# %% [markdown]
# # Sprint - 1 : Data Understanding & Preprocessing

# %%
# 
# Data Understanding and Preprocessing

# %% [markdown]
# ### Step -1 : Data Collection and Loading.

# %%
# We have the data in the form of csv file. We will use pandas library to load the data into a dataframe.
import pandas as pd

path = "./data/train.csv"
df = pd.read_csv(path,sep=";")

# validating the data
print("Number of rows :",df.shape[0], "Number of columns :",df.shape[1])
# Out:
# Number of rows : 45211 Number of columns : 17

# %% [markdown]
# ### Step - 2 : Data Inspections

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
# Split the Categorical and numerical data 

# divided the columns into the 2 types
 
num_col = df.select_dtypes(include=["int64","float64"]).columns
cat_col = df.select_dtypes(include=["object"]).columns

# %%
print(num_col)
print(cat_col)
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# ### Step - 3 : Data Cleaning

# %%
# Missing Values 
df.isnull().sum() # we found no misssing values
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
# unique Values
# unique values for only categircal data 
for i in cat_col:
    print(f"Unique values in {i} is : {df[i].unique()}")
# Out:
# Unique values in job is : ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
# Unique values in marital is : ['married' 'single' 'divorced']
# Unique values in education is : ['tertiary' 'secondary' 'unknown' 'primary']
# Unique values in default is : ['no' 'yes']
# Unique values in housing is : ['yes' 'no']
# Unique values in loan is : ['no' 'yes']
# Unique values in contact is : ['unknown' 'cellular' 'telephone']
# Unique values in month is : ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# Unique values in poutcome is : ['unknown' 'failure' 'other' 'success']
# Unique values in y is : ['no' 'yes']

# %%
# Checking for the duplicate values
print("Number of duplicate values in the dataset is : ",df.duplicated().sum())  # no duplicates
# Out:
# Number of duplicate values in the dataset is :  0

# %%
num_col
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
# Standardizing the Column Names
# changing the names of columns to understandable format
df.rename(columns={"y":"target"}, inplace=True)
df.rename(columns={"default":"default_credit"}, inplace=True)
df.rename(columns={"housing":"housing_loan"}, inplace=True)
df.rename(columns={"loan":"personal_loan"}, inplace=True)
df.rename(columns={"contact":"contact_type"}, inplace=True)
df.rename(columns={"poutcome":"previous_outcome"}, inplace=True)
df.rename(columns={"pdays":"no_time_contacted_days_before"}, inplace=True)
df.rename(columns={"duration":"last_call_duration"}, inplace=True)
df.rename(columns={"campaign":"contacts_in_campaign"}, inplace=True)
df.rename(columns={"previous":"contacted_in_before_campaing"}, inplace=True)

# %%
# names has changed 
num_col = df.select_dtypes(include=["int64","float64"]).columns
cat_col = df.select_dtypes(include=["object"]).columns
print(num_col)
print(cat_col)
# Out:
# Index(['age', 'balance', 'day', 'last_call_duration', 'contacts_in_campaign',
#        'no_time_contacted_days_before', 'contacted_in_before_campaing'],
#       dtype='object')
# Index(['job', 'marital', 'education', 'default_credit', 'housing_loan',
#        'personal_loan', 'contact_type', 'month', 'previous_outcome', 'target'],
#       dtype='object')

# %%
df.head()
# Out:
#    age           job  marital  education default_credit  balance housing_loan  \
# 0   58    management  married   tertiary             no     2143          yes
# 1   44    technician   single  secondary             no       29          yes
# 2   33  entrepreneur  married  secondary             no        2          yes
# 3   47   blue-collar  married    unknown             no     1506          yes
# 4   33       unknown   single    unknown             no        1           no
#
#   personal_loan contact_type  day month  last_call_duration  \
# 0            no      unknown    5   may                 261
# 1            no      unknown    5   may                 151
# 2           yes      unknown    5   may                  76
# 3            no      unknown    5   may                  92
# 4            no      unknown    5   may                 198
#
#    contacts_in_campaign  no_time_contacted_days_before  \
# 0                     1                             -1
# ...

# %% [markdown]
# ### Step - 4 : Exploratory Data Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import math

# %% [markdown]
# #### Uni variant Analysis

# %% [markdown]
# ##### Numerical columns

# %%
df[num_col]
# Out:
#        age  balance  day  last_call_duration  contacts_in_campaign  \
# 0       58     2143    5                 261                     1
# 1       44       29    5                 151                     1
# 2       33        2    5                  76                     1
# 3       47     1506    5                  92                     1
# 4       33        1    5                 198                     1
# ...    ...      ...  ...                 ...                   ...
# 45206   51      825   17                 977                     3
# 45207   71     1729   17                 456                     2
# 45208   72     5715   17                1127                     5
# 45209   57      668   17                 508                     4
# 45210   37     2971   17                 361                     2
#
#        no_time_contacted_days_before  contacted_in_before_campaing
# 0                                 -1                             0
# ...

# %%
for col in num_col:
    plt.figure(figsize=(8,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
for col in num_col:
    plt.figure(figsize=(8,4))
    sns.boxplot(df[col])
    plt.title(f"Distribution of {col}")
plt.show()

# %%
df.describe()
# Out:
#                 age        balance           day  last_call_duration  \
# count  45211.000000   45211.000000  45211.000000        45211.000000
# mean      40.936210    1362.272058     15.806419          258.163080
# std       10.618762    3044.765829      8.322476          257.527812
# min       18.000000   -8019.000000      1.000000            0.000000
# 25%       33.000000      72.000000      8.000000          103.000000
# 50%       39.000000     448.000000     16.000000          180.000000
# 75%       48.000000    1428.000000     21.000000          319.000000
# max       95.000000  102127.000000     31.000000         4918.000000
#
#        contacts_in_campaign  no_time_contacted_days_before  \
# count          45211.000000                   45211.000000
# mean               2.763841                      40.197828
# std                3.098021                     100.128746
# min                1.000000                      -1.000000
# ...

# %%
for col in num_col:
    print("Skewness of the",col,"is :",df[col].skew())
# Out:
# Skewness of the age is : 0.6848179257252598
# Skewness of the balance is : 8.360308326166326
# Skewness of the day is : 0.09307901402122411
# Skewness of the last_call_duration is : 3.144318099423456
# Skewness of the contacts_in_campaign is : 4.898650166179674
# Skewness of the no_time_contacted_days_before is : 2.6157154736563477
# Skewness of the contacted_in_before_campaing is : 41.84645447266292

# %% [markdown]
# ### Insights
#
# - Here we can find the Total of 7 Numerical Columns and 10 categirical columns in the entire data set
# - we have heavily skewed data for the balance, Last call duration, contacts in campaign, contacts before campaign
# -

# %%
df[cat_col]
# Out:
#                 job   marital  education default_credit housing_loan  \
# 0        management   married   tertiary             no          yes
# 1        technician    single  secondary             no          yes
# 2      entrepreneur   married  secondary             no          yes
# 3       blue-collar   married    unknown             no          yes
# 4           unknown    single    unknown             no           no
# ...             ...       ...        ...            ...          ...
# 45206    technician   married   tertiary             no           no
# 45207       retired  divorced    primary             no           no
# 45208       retired   married  secondary             no           no
# 45209   blue-collar   married  secondary             no           no
# 45210  entrepreneur   married  secondary             no           no
#
#       personal_loan contact_type month previous_outcome target
# 0                no      unknown   may          unknown     no
# ...

# %%
# Distribution of a single numerical column  
for col in cat_col:
    plt.figure(figsize=(10, 5))
    sns.countplot(data = df,x=col)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.xlabel('Values')
    plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Insights
# 1.

# %% [markdown]
# ##### Bivariate Analysis

# %%
for col in num_col:
    plt.figure(figsize=(8,4))
    sns.boxplot(
        x='target',
        y=col,
        data=df
    )
    plt.title(f"{col} vs Target")
    plt.show()

# %%
for col in selected_num:
    print(df.groupby("target")[col].mean())
# Out:
# target
# no     40.838986
# yes    41.670070
# Name: age, dtype: float64
# target
# no     1303.714969
# yes    1804.267915
# Name: balance, dtype: float64
# target
# no     221.182806
# yes    537.294574
# Name: last_call_duration, dtype: float64
# target
# no     2.846350
# yes    2.141047
# Name: contacts_in_campaign, dtype: float64

# %%
for col in cat_col:
    sns.countplot(
        data=df,
        y=col,
        hue="target",
        palette="pastel",
        orient="h"
    )
    plt.title(f"Horizontal Count Plot of {col}")
    plt.show()

# %%
for col in cat_col:
    print(pd.crosstab(
        df[col],
        df['target'],
        normalize='index'
    ))
    print("=="*20)
# Out:
# target               no       yes
# job
# admin.         0.877973  0.122027
# blue-collar    0.927250  0.072750
# entrepreneur   0.917283  0.082717
# housemaid      0.912097  0.087903
# management     0.862444  0.137556
# retired        0.772085  0.227915
# self-employed  0.881571  0.118429
# services       0.911170  0.088830
# student        0.713220  0.286780
# technician     0.889430  0.110570
# unemployed     0.844973  0.155027
# unknown        0.881944  0.118056
# ...
# target          no       yes
# marital
# divorced  0.880545  0.119455
# married   0.898765  0.101235
# single    0.850508  0.149492
# ...
# target           no       yes
# education
# primary    0.913735  0.086265
# secondary  0.894406  0.105594
# tertiary   0.849936  0.150064
# unknown    0.864297  0.135703
# ...
# target                no       yes
# default_credit
# no              0.882039  0.117961
# yes             0.936196  0.063804
# ...
# target              no       yes
# housing_loan
# no            0.832976  0.167024
# ...

# %% [markdown]
# ### Insights
# 1. From the Jobs, Most people from the Management roles are choosing to subscribe term deposit
# 2. From the Defualt credit people who has credit do not choose to subscribe for the term deposit
# 3. People who have no personal loan choose more to the term deposits.
# 4. Most people who have enrolled are through cellular communications.
# 5. Most of the subsriptions are happening in the month may.

# %%
sns.heatmap(df[num_col].corr(),annot=True)
plt.show()

# %%
sns.heatmap(selected_num.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Insights
# 1.

# %% [markdown]
# ## Step : 5 Outliers Treatment

# %%
for col in num_col:
    print("Skewness of the",col,"is :",df[col].skew())
# Out:
# Skewness of the age is : 0.6848179257252598
# Skewness of the balance is : 8.360308326166326
# Skewness of the day is : 0.09307901402122411
# Skewness of the last_call_duration is : 3.144318099423456
# Skewness of the contacts_in_campaign is : 4.898650166179674
# Skewness of the no_time_contacted_days_before is : 2.6157154736563477
# Skewness of the contacted_in_before_campaing is : 41.84645447266292

# %% [markdown]
# 1. here we are using other features but the **no_time_contacted_days_before**
# 2. we need to transform the features as balance, and last call duration
# 3. The remaining columsn

# %% [markdown]
# #### Numerical Data Trasformations

# %%
df["contacted_in_before_campaing"].unique()
# Out:
# array([  0,   3,   1,   4,   2,  11,  16,   6,   5,  10,  12,   7,  18,
#          9,  21,   8,  14,  15,  26,  37,  13,  25,  20,  27,  17,  23,
#         38,  29,  24,  51, 275,  22,  19,  30,  58,  28,  32,  40,  55,
#         35,  41])

# %%
df["balance_log"] = np.log1p(df["balance"] - df["balance"].min() + 1)

# %%
df["duration_log"] = np.log1p(df["last_call_duration"])

# %%
df["duration_log"].skew()
# Out:
# np.float64(-0.45416422447582144)

# %%
df["duration_log"].plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df["balance_log"].skew()
# Out:
# np.float64(1.4669168081279749)

# %%
df["balance_log"].plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Step : 6 Feature Encoding & Selection

# %%
x = df.drop(columns=["balance","day","month","last_call_duration","no_time_contacted_days_before","target"])

# %%
x
# Out:
#        age           job   marital  education default_credit housing_loan  \
# 0       58    management   married   tertiary             no          yes
# 1       44    technician    single  secondary             no          yes
# 2       33  entrepreneur   married  secondary             no          yes
# 3       47   blue-collar   married    unknown             no          yes
# 4       33       unknown    single    unknown             no           no
# ...    ...           ...       ...        ...            ...          ...
# 45206   51    technician   married   tertiary             no           no
# 45207   71       retired  divorced    primary             no           no
# 45208   72       retired   married  secondary             no           no
# 45209   57   blue-collar   married  secondary             no           no
# 45210   37  entrepreneur   married  secondary             no           no
#
#       personal_loan contact_type  contacts_in_campaign  \
# ...

# %%
print(x.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default_credit', 'housing_loan',
#        'personal_loan', 'contact_type', 'contacts_in_campaign',
#        'contacted_in_before_campaing', 'previous_outcome', 'balance_log',
#        'duration_log'],
#       dtype='object')

# %%
# numerical cols : age, contacts_in _campign, contac_in_before_campaign, balance_log, duration_log

# ordinal_encode : education, 
# one_hot encode : job, marital, previous_outcome, contact_type
# label_encoding : default_credit, housing_loan, personal_loan, {0,1}

# %%
x["education"].unique()
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %%
pd.crosstab(df['education'],df['target'],normalize='index')
# Out:
# target           no       yes
# education
# primary    0.913735  0.086265
# secondary  0.894406  0.105594
# tertiary   0.849936  0.150064
# unknown    0.864297  0.135703

# %%
# ordinal encoding 
education_map = {'unknown':0,'primary':1,'secondary':2,'tertiary':3}
x["education"] = x["education"].map(education_map)

# %%
x
# Out:
#        age           job   marital  education default_credit housing_loan  \
# 0       58    management   married          3             no          yes
# 1       44    technician    single          2             no          yes
# 2       33  entrepreneur   married          2             no          yes
# 3       47   blue-collar   married          0             no          yes
# 4       33       unknown    single          0             no           no
# ...    ...           ...       ...        ...            ...          ...
# 45206   51    technician   married          3             no           no
# 45207   71       retired  divorced          1             no           no
# 45208   72       retired   married          2             no           no
# 45209   57   blue-collar   married          2             no           no
# 45210   37  entrepreneur   married          2             no           no
#
#       personal_loan contact_type  contacts_in_campaign  \
# ...

# %%
one_hot_cols = ["job","marital","previous_outcome","contact_type"]

one_hot_encoded = pd.get_dummies(x[one_hot_cols],dtype=int,drop_first=True)

# %%
x = pd.concat([x.drop(columns=one_hot_cols),one_hot_encoded],axis=1)

# %%
x.head()
# Out:
#    age  education default_credit housing_loan personal_loan  \
# 0   58          3             no          yes            no
# 1   44          2             no          yes            no
# 2   33          2             no          yes           yes
# 3   47          0             no          yes            no
# 4   33          0             no           no            no
#
#    contacts_in_campaign  contacted_in_before_campaing  balance_log  \
# 0                     1                             0     9.226607
# 1                     1                             0     8.993427
# 2                     1                             0     8.990068
# 3                     1                             0     9.161885
# 4                     1                             0     8.989943
#
#    duration_log  job_blue-collar  ...  job_technician  job_unemployed  \
# 0      5.568345                0  ...               0               0
# ...

# %%
maps = {"no": 0,"yes": 1}

x["default_credit"] = x["default_credit"].map(maps)
x["housing_loan"] = x["housing_loan"].map(maps)
x["personal_loan"] = x["personal_loan"].map(maps)

# %%
x.head()
# Out:
#    age  education  default_credit  housing_loan  personal_loan  \
# 0   58          3               0             1              0
# 1   44          2               0             1              0
# 2   33          2               0             1              1
# 3   47          0               0             1              0
# 4   33          0               0             0              0
#
#    contacts_in_campaign  contacted_in_before_campaing  balance_log  \
# 0                     1                             0     9.226607
# 1                     1                             0     8.993427
# 2                     1                             0     8.990068
# 3                     1                             0     9.161885
# 4                     1                             0     8.989943
#
#    duration_log  job_blue-collar  ...  job_technician  job_unemployed  \
# 0      5.568345                0  ...               0               0
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(x.corr())
# Out:
# <Axes: >

# %% [markdown]
# ### Insight
# 1. we can say we have absoultly no correlation in the data points with the each other.
# 2. It is ready for the model training

# %% [markdown]
# ### Step : 7 Feature Scaling

# %%
# Actually we are using the two set of models like linear models and decision based models 
# where decision based models so not require the scaling and trasformation so we use two diffrent data set for the analysis.

x.head() # for the model decsisions
# Out:
#    age  education  default_credit  housing_loan  personal_loan  \
# 0   58          3               0             1              0
# 1   44          2               0             1              0
# 2   33          2               0             1              1
# 3   47          0               0             1              0
# 4   33          0               0             0              0
#
#    contacts_in_campaign  contacted_in_before_campaing  balance_log  \
# 0                     1                             0     9.226607
# 1                     1                             0     8.993427
# 2                     1                             0     8.990068
# 3                     1                             0     9.161885
# 4                     1                             0     8.989943
#
#    duration_log  job_blue-collar  ...  job_technician  job_unemployed  \
# 0      5.568345                0  ...               0               0
# ...

# %%
X_train
# Out:
#             age  education  default_credit  housing_loan  personal_loan  \
# 24001 -0.460434  -0.074528               0             0              0
# 43409 -1.589641  -0.074528               0             0              0
# 20669  0.292371  -0.074528               0             1              0
# 18810  0.668773  -0.074528               0             0              0
# 23130 -0.272233  -0.074528               0             0              0
# ...         ...        ...             ...           ...            ...
# 17958  0.856974  -0.074528               0             1              0
# 15941 -0.460434  -0.074528               0             1              0
# 16952  0.386471  -0.074528               0             1              0
# 34781 -1.307339   1.209668               0             1              0
# 44229  1.797980  -2.642919               0             0              0
#
#        contacts_in_campaign  contacted_in_before_campaing  balance_log  \
# ...

# %%
y = df["target"].map(maps)

# %%
y.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
sns.countplot(data=df,y="target")
# Out:
# <Axes: xlabel='count', ylabel='target'>

# %% [markdown]
# ### Insight :
# 1. Data is hugely imbalenced for the target column

# %% [markdown]
# ## Step : 8 Train - Test - split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

num_cols = ["age",
            "contacts_in_campaign",
            "contacted_in_before_campaing",
            "balance_log",
            "duration_log",
            "education"]

X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])

# %%
print("X - Training length :",len(X_train))
print("X - Testing length :",len(X_test))
print("y - Training length :",len(y_train))
print("y - Testing length :",len(y_test))

# %% [markdown]
# # Sprint - 2 : Model Building & Validation

# %% [markdown]
# ### Step - 1 : Baseline Model Buliding

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report,log_loss

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# %% [markdown]
# #### Validation on Train Data

# %%
# Confusion matrix
confusion_matrix(y_train,y_pred_train)
# Out:
# array([[31161,   776],
#        [ 2847,  1384]])

# %%
print(classification_report(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95     31937
#            1       0.64      0.33      0.43      4231
#
#     accuracy                           0.90     36168
#    macro avg       0.78      0.65      0.69     36168
# weighted avg       0.88      0.90      0.89     36168

# %% [markdown]
# #### Validation on Test Data

# %%
# Confusion matrix
confusion_matrix(y_test,y_pred_test)
# Out:
# array([[7796,  189],
#        [ 717,  341]])

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      7985
#            1       0.64      0.32      0.43      1058
#
#     accuracy                           0.90      9043
#    macro avg       0.78      0.65      0.69      9043
# weighted avg       0.88      0.90      0.88      9043

# %% [markdown]
# ### Train_loss and Test_loss using Log_loss

# %%
train_loss = log_loss(y_train,y_pred_train)
test_loss = log_loss(y_test,y_pred_test)

print(train_loss)
print(test_loss)
# Out:
# 3.6105440231356845
# 3.6111412109410748

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd
import math

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
path = "../data/train.csv"
df = pd.read_csv(path,sep=";")

# Standardizing the Column Names
# changing the names of columns to understandable format
df.rename(columns={"y":"target"}, inplace=True)
df.rename(columns={"default":"default_credit"}, inplace=True)
df.rename(columns={"housing":"housing_loan"}, inplace=True)
df.rename(columns={"loan":"personal_loan"}, inplace=True)
df.rename(columns={"contact":"contact_type"}, inplace=True)
df.rename(columns={"poutcome":"previous_outcome"}, inplace=True)
df.rename(columns={"pdays":"no_time_contacted_days_before"}, inplace=True)
df.rename(columns={"duration":"last_call_duration"}, inplace=True)
df.rename(columns={"campaign":"contacts_in_campaign"}, inplace=True)
df.rename(columns={"previous":"contacted_in_before_campaing"}, inplace=True)


# names has changed 
num_col = df.select_dtypes(include=["int64","float64"]).columns
cat_col = df.select_dtypes(include=["object"]).columns
print(num_col)
print(cat_col)

df["balance_log"] = np.log1p(df["balance"] - df["balance"].min() + 1)
df["duration_log"] = np.log1p(df["last_call_duration"])




x = df.drop(columns=["balance","day","month","last_call_duration","no_time_contacted_days_before","target"])


# Encoding

# Label Encoding
maps = {"no": 0,"yes": 1}

x["default_credit"] = x["default_credit"].map(maps)
x["housing_loan"] = x["housing_loan"].map(maps)
x["personal_loan"] = x["personal_loan"].map(maps)

# ordinal encoding 
education_map = {'unknown':0,'primary':1,'secondary':2,'tertiary':3}
x["education"] = x["education"].map(education_map)

# one hot encoding
one_hot_cols = ["job","marital","previous_outcome","contact_type"]
one_hot_encoded = pd.get_dummies(x[one_hot_cols],dtype=int,drop_first=True)


# Making X and Y Data Values
x = pd.concat([x.drop(columns=one_hot_cols),one_hot_encoded],axis=1)
y = df["target"].map(maps)


# splitting
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# Feature Scaling 
scaler = StandardScaler()

num_cols = ["age",
            "contacts_in_campaign",
            "contacted_in_before_campaing",
            "balance_log",
            "duration_log"]

X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])



print("X - Training length :",len(X_train))
print("X - Testing length :",len(X_test))
print("y - Training length :",len(y_train))
print("y - Testing length :",len(y_test))
# Out:
# Index(['age', 'balance', 'day', 'last_call_duration', 'contacts_in_campaign',
#        'no_time_contacted_days_before', 'contacted_in_before_campaing'],
#       dtype='object')
# Index(['job', 'marital', 'education', 'default_credit', 'housing_loan',
#        'personal_loan', 'contact_type', 'month', 'previous_outcome', 'target'],
#       dtype='object')
# X - Training length : 36168
# X - Testing length : 9043
# y - Training length : 36168
# y - Testing length : 9043

# %%
joblib.dump(
    scaler,
    "scaler.pkl"
)
# Out:
# ['scaler.pkl']

# %%
print(df["balance"].min())
# Out:
# -8019

# %% [markdown]
# ### Step - 2 : Training Multiple Models

# %%
# Alogirthms
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC

# Metrics
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,log_loss,roc_auc_score

# %%
knn_model = KNeighborsClassifier()
nb_model = BernoulliNB()
log_model = LogisticRegression()
gb_model = GradientBoostingClassifier()
xgb_model = XGBClassifier()
svm_model = SVC()

# %% [markdown]
# ### Step 3 : Model Evaluation | Overfit underfit Observation | Models Report

# %%
models = {
    "Logistic Regression": log_model,
    "Gradient Boosting": gb_model,
    "Xtream Gradient Boosting": xgb_model,
    "SVM": svm_model,
    "Knn": knn_model,
    "Naive Bayes": nb_model
}

results = []

for name, model in models.items():

    # Train Model
    model.fit(X_train, y_train)

    # Predictions
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)

    # Training Metrics
    train_accuracy = accuracy_score(y_train, train_pred)
    train_precision = precision_score(y_train, train_pred)
    train_recall = recall_score(y_train, train_pred)
    train_f1 = f1_score(y_train, train_pred)

    # Testing Metrics
    test_accuracy = accuracy_score(y_test, test_pred)
    test_precision = precision_score(y_test, test_pred)
    test_recall = recall_score(y_test, test_pred)
    test_f1 = f1_score(y_test, test_pred)

    # Overfitting / Underfitting Check
    gap = train_accuracy - test_accuracy

    if train_accuracy < 0.70 and test_accuracy < 0.70:
        status = "Underfitting"

    elif gap > 0.10:
        status = "Overfitting"

    else:
        status = "Good Fit"

    results.append({
        "Model": name,
        "Train Accuracy": round(train_accuracy, 4),
        "Test Accuracy": round(test_accuracy, 4),
        "Precision": round(test_precision, 4),
        "Recall": round(test_recall, 4),
        "F1 Score": round(test_f1, 4),
        "Status": status
    })

results_df = pd.DataFrame(results)

# %%
results_df
# Out:
#                       Model  Train Accuracy  Test Accuracy  Precision  Recall  \
# 0       Logistic Regression          0.8997         0.8998     0.6429  0.3233
# 1         Gradient Boosting          0.9064         0.9022     0.6390  0.3781
# 2  Xtream Gradient Boosting          0.9366         0.8980     0.5974  0.3941
# 3                       SVM          0.9000         0.8964     0.6734  0.2221
# 4                       Knn          0.9192         0.8899     0.5531  0.3053
# 5               Naive Bayes          0.8770         0.8756     0.4564  0.3318
#
#    F1 Score    Status
# 0    0.4302  Good Fit
# 1    0.4751  Good Fit
# 2    0.4749  Good Fit
# 3    0.3340  Good Fit
# 4    0.3934  Good Fit
# 5    0.3842  Good Fit

# %%
results_df.sort_values(
    by="Recall",
    ascending=False
)
# Out:
#                       Model  Train Accuracy  Test Accuracy  Precision  Recall  \
# 2  Xtream Gradient Boosting          0.9366         0.8980     0.5974  0.3941
# 1         Gradient Boosting          0.9064         0.9022     0.6390  0.3781
# 5               Naive Bayes          0.8770         0.8756     0.4564  0.3318
# 0       Logistic Regression          0.8997         0.8998     0.6429  0.3233
# 4                       Knn          0.9192         0.8899     0.5531  0.3053
# 3                       SVM          0.9000         0.8964     0.6734  0.2221
#
#    F1 Score    Status
# 2    0.4749  Good Fit
# 1    0.4751  Good Fit
# 5    0.3842  Good Fit
# 0    0.4302  Good Fit
# 4    0.3934  Good Fit
# 3    0.3340  Good Fit

# %%
for name, model in models.items():
    pred = model.predict(X_test)

    print(f"\n{name}")
    print("="*50)

    cm = confusion_matrix(y_test, pred)
    print(cm)
# Out:
# Logistic Regression
# ...
# [[7795  190]
#  [ 716  342]]
#
# Gradient Boosting
# ...
# [[7759  226]
#  [ 658  400]]
#
# Xtream Gradient Boosting
# ...
# [[7704  281]
#  [ 641  417]]
#
# SVM
# ...
# [[7871  114]
#  [ 823  235]]
#
# Knn
# ...
# [[7724  261]
#  [ 735  323]]
#
# Naive Bayes
# ...
# [[7567  418]
#  [ 707  351]]

# %% [markdown]
# ### Changing the Threshold and Evaluating

# %%
model
# Out:
# BernoulliNB()

# %%
y_prob = gb_model.predict_proba(X_test)[:,1]

y_pred = (y_prob >= 0.30).astype(int)

# %%
pred = gb_model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(9043,))

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[7421,  564],
#        [ 424,  634]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      7985
#            1       0.53      0.60      0.56      1058
#
#     accuracy                           0.89      9043
#    macro avg       0.74      0.76      0.75      9043
# weighted avg       0.90      0.89      0.89      9043

# %% [markdown]
# ### Step 4 : AOC ROC Analysis

# %%
results = []

for name, model in models.items():

    # Predictions
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)

    # Probabilities
    if hasattr(model, "predict_proba"):
        train_prob = model.predict_proba(X_train)[:, 1]
        test_prob = model.predict_proba(X_test)[:, 1]

    else:
        # For SVM if probability=False
        train_prob = None
        test_prob = None

    # Train Metrics
    train_accuracy = accuracy_score(y_train, train_pred)

    # Test Metrics
    test_accuracy = accuracy_score(y_test, test_pred)
    precision = precision_score(y_test, test_pred)
    recall = recall_score(y_test, test_pred)
    f1 = f1_score(y_test, test_pred)

    # ROC-AUC & Log Loss
    if test_prob is not None:

        roc_auc = roc_auc_score(y_test, test_prob)

        test_logloss = log_loss(
            y_test,
            test_prob
        )

    else:

        roc_auc = None
        test_logloss = None

    # Fit Analysis

    gap = train_accuracy - test_accuracy

    if train_accuracy < 0.75 and test_accuracy < 0.75:
        status = "Underfitting"

    elif gap > 0.10:
        status = "Overfitting"

    else:
        status = "Good Fit"

    results.append({
        "Model": name,
        "Train Accuracy": round(train_accuracy, 4),
        "Test Accuracy": round(test_accuracy, 4),
        "Precision": round(precision, 4),
        "Recall": round(recall, 4),
        "F1 Score": round(f1, 4),
        "ROC AUC": round(roc_auc, 4) if roc_auc else None,
        "Log Loss": round(test_logloss, 4) if test_logloss else None,
        "Status": status
    })

results_df = pd.DataFrame(results)

results_df.sort_values(
    by=["Recall", "ROC AUC"],
    ascending=False
)
# Out:
#                       Model  Train Accuracy  Test Accuracy  Precision  Recall  \
# 2  Xtream Gradient Boosting          0.9366         0.8980     0.5974  0.3941
# 1         Gradient Boosting          0.9064         0.9022     0.6390  0.3781
# 5               Naive Bayes          0.8770         0.8756     0.4564  0.3318
# 0       Logistic Regression          0.8997         0.8998     0.6429  0.3233
# 4                       Knn          0.9192         0.8899     0.5531  0.3053
# 3                       SVM          0.9000         0.8964     0.6734  0.2221
#
#    F1 Score  ROC AUC  Log Loss    Status
# 2    0.4749   0.8976    0.2381  Good Fit
# 1    0.4751   0.9025    0.2310  Good Fit
# 5    0.3842   0.8131    0.3200  Good Fit
# 0    0.4302   0.8905    0.2418  Good Fit
# 4    0.3934   0.8036    1.1729  Good Fit
# 3    0.3340      NaN       NaN  Good Fit

# %%
results_df["Accuracy Gap"] = (
    results_df["Train Accuracy"]
    - results_df["Test Accuracy"]
).round(4)

# %% [markdown]
# ### Step : 5 Model Comparison Table

# %%
results_df.sort_values(
    by=["Recall", "ROC AUC"],
    ascending=False
)
# Out:
#                       Model  Train Accuracy  Test Accuracy  Precision  Recall  \
# 2  Xtream Gradient Boosting          0.9366         0.8980     0.5974  0.3941
# 1         Gradient Boosting          0.9064         0.9022     0.6390  0.3781
# 5               Naive Bayes          0.8770         0.8756     0.4564  0.3318
# 0       Logistic Regression          0.8997         0.8998     0.6429  0.3233
# 4                       Knn          0.9192         0.8899     0.5531  0.3053
# 3                       SVM          0.9000         0.8964     0.6734  0.2221
#
#    F1 Score  ROC AUC  Log Loss    Status  Accuracy Gap
# 2    0.4749   0.8976    0.2381  Good Fit        0.0386
# 1    0.4751   0.9025    0.2310  Good Fit        0.0042
# 5    0.3842   0.8131    0.3200  Good Fit        0.0014
# 0    0.4302   0.8905    0.2418  Good Fit       -0.0001
# 4    0.3934   0.8036    1.1729  Good Fit        0.0293
# 3    0.3340      NaN       NaN  Good Fit        0.0036

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

plt.figure(figsize=(10,6))

for name, model in models.items():

    if hasattr(model, "predict_proba"):

        probs = model.predict_proba(X_test)[:,1]

        fpr, tpr, _ = roc_curve(
            y_test,
            probs
        )

        auc = roc_auc_score(
            y_test,
            probs
        )

        plt.plot(
            fpr,
            tpr,
            label=f"{name} (AUC={auc:.3f})"
        )

plt.plot(
    [0,1],
    [0,1],
    linestyle="--"
)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()

plt.show()

# %% [markdown]
# ###  Models selecting for the optimization and futher updations
#
# 1. Gradient Boosting
# 2. Xgb Boosting
# 3. Logistic regression

# %% [markdown]
# #### Trying for the Light GBM

# %%
from lightgbm import LGBMClassifier

lgb_model = LGBMClassifier(random_state=42)

lgb_model.fit(X_train, y_train)

pred = lgb_model.predict(X_test)
prob = lgb_model.predict_proba(X_test)[:,1]
# Out:
# [LightGBM] [Info] Number of positive: 4231, number of negative: 31937
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001525 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 705
# [LightGBM] [Info] Number of data points in the train set: 36168, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116982 -> initscore=-2.021327
# [LightGBM] [Info] Start training from score -2.021327

# %%
recall_score(y_test,pred)
# Out:
# 0.3827977315689981

# %%
tr_pred = lgb_model.predict(X_train)

recall_score(y_train,tr_pred)
# Out:
# 0.4760103994327582

# %% [markdown]
# here we are having the XGB and GB heavy models which require more computation models
# - so We can include the LightGB.
# - Where : Gradient Boosting < LightGBM ≈ XGBoost
#
# - We can even consider the LightGB
#
# So we are goint to choose the models such as
#
# 1. GB
# 2. XGB
# 3. LightGB

# %% [markdown]
# # Sprint 3 : Model Optimization and Final Model

# %% [markdown]
# ### Step 1 : Feature Importance Analysis
#
# - Which features are actually helping the model make decisions?

# %%
feature_importance_gb = pd.DataFrame({"Feature": X_train.columns,"Importance": gb_model.feature_importances_})
feature_importance_gb = feature_importance_gb.sort_values(by="Importance",ascending=False)

# %%
feature_importance_gb.head(10)
# Out:
#                          Feature  Importance
# 8                   duration_log    0.540455
# 23      previous_outcome_success    0.221831
# 26          contact_type_unknown    0.054116
# 3                   housing_loan    0.053901
# 0                            age    0.051599
# 6   contacted_in_before_campaing    0.020741
# 7                    balance_log    0.017198
# 5           contacts_in_campaign    0.009104
# 4                  personal_loan    0.005294
# 20               marital_married    0.005231

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=feature_importance_gb.head(15),
    x="Importance",
    y="Feature"
)

plt.title("Gradient Boosting Feature Importance")
plt.show()

# %%
feature_importance_xgb = pd.DataFrame({"Feature": X_train.columns,"Importance": xgb_model.feature_importances_})
feature_importance_xgb = feature_importance_gb.sort_values(by="Importance",ascending=False)

# %%
feature_importance_xgb.head(10)
# Out:
#                          Feature  Importance
# 8                   duration_log    0.540440
# 23      previous_outcome_success    0.221831
# 26          contact_type_unknown    0.054116
# 3                   housing_loan    0.053901
# 0                            age    0.051598
# 6   contacted_in_before_campaing    0.020771
# 7                    balance_log    0.017094
# 5           contacts_in_campaign    0.009225
# 4                  personal_loan    0.005295
# 20               marital_married    0.005231

# %%
feature_importance_lgb = pd.DataFrame({"Feature": X_train.columns,"Importance": lgb_model.feature_importances_})
feature_importance_lgb = feature_importance_lgb.sort_values(by="Importance",ascending=False)

# %%
feature_importance_lgb.head(10)
# Out:
#                          Feature  Importance
# 8                   duration_log         700
# 7                    balance_log         598
# 0                            age         546
# 5           contacts_in_campaign         182
# 6   contacted_in_before_campaing         140
# 1                      education         104
# 3                   housing_loan          92
# 26          contact_type_unknown          88
# 23      previous_outcome_success          74
# 4                  personal_loan          67

# %%
top_features = list(feature_importance_gb["Feature"].head(10))
least_features = list(feature_importance_gb["Feature"].tail(10))

print(top_features)
print(least_features)
# Out:
# ['duration_log', 'previous_outcome_success', 'contact_type_unknown', 'housing_loan', 'age', 'contacted_in_before_campaing', 'balance_log', 'contacts_in_campaign', 'personal_loan', 'marital_married']
# ['job_housemaid', 'job_management', 'job_unknown', 'default_credit', 'job_technician', 'job_self-employed', 'job_entrepreneur', 'job_retired', 'job_unemployed', 'job_services']

# %% [markdown]
# ### Insight
#
# Customer interaction history and call duration were significantly
# more influential than demographic job categories.
#
# Several job-related features contributed very little to model performance.

# %% [markdown]
# ### Step : 2 Feature Selection

# %% [markdown]
# From feature Selection we can Reduce noise and simplify the model.
# - Removed low-importance features identified during feature importance analysis.
# - Retrained Gradient Boosting model using the reduced feature set.

# %%
low_features = [
    'job_housemaid',
    'job_management',
    'job_unknown',
    'default_credit',
    'job_technician',
    'job_self-employed',
    'job_entrepreneur',
    'job_retired',
    'job_unemployed',
    'job_services'
]

X_train_fs = X_train.drop(columns=low_features)
X_test_fs = X_test.drop(columns=low_features)

# %%
gb_fs = GradientBoostingClassifier(random_state=42)
gb_fs.fit(X_train_fs,y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
pred = gb_fs.predict(X_test_fs)

print(accuracy_score(y_test,pred))
print(precision_score(y_test,pred))
print(recall_score(y_test,pred))
print(f1_score(y_test,pred))
# Out:
# 0.9032400751962845
# 0.6423017107309487
# 0.390359168241966
# 0.48559670781893005

# %%
lgb_fs = LGBMClassifier(random_state=42)
lgb_fs.fit(X_train_fs,y_train)
pred = lgb_fs.predict(X_test_fs)

# Evaluation 
print(accuracy_score(y_test,pred))
print(precision_score(y_test,pred))
print(recall_score(y_test,pred))
print(f1_score(y_test,pred))
# Out:
# [LightGBM] [Info] Number of positive: 4231, number of negative: 31937
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003191 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 685
# [LightGBM] [Info] Number of data points in the train set: 36168, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116982 -> initscore=-2.021327
# [LightGBM] [Info] Start training from score -2.021327
# 0.9014707508570164
# 0.6270928462709284
# 0.389413988657845
# 0.480466472303207

# %% [raw]
# Results
# ----------
# Metric	    Baseline GB	GB_FS   LightGBM
# Accuracy	0.9021	 0.9032     0.9014
# Precision	0.6384	 0.6423     0.6270
# Recall	    0.3771	 0.3904     0.3894
# F1 Score	0.4742	 0.4856     0.4804

# %% [markdown]
# ### Insight
#
# 1. Removing low-importance features slightly improved all evaluation metrics.
# 2. The removed features were contributing noise rather than useful information.

# %% [markdown]
# #### Data variables Used for the processing

# %% [raw]
# Data Dictionary
#
# X_Train_fs : Training data from the Selected Feature
# X_test_fs  : Testing data from the Selected Feature
#
# X_train_smote, y_train_smote : Data from the Smote Using the X_train_fs, y_train
#
#
# # models
# -----------
# gb_fs  : Model trained on X_train_fs,y_train
# lbg_fs : Model trained on X_train_fs,y_train
#
# lgb_bal : Model Trained on X_train_fs and balanced Data

# %% [markdown]
# ### Step 3 : Class Imbalence handling

# %%
y_train.value_counts(normalize=True)
# Out:
# target
# 0    0.883018
# 1    0.116982
# Name: proportion, dtype: float64

# %% [markdown]
# #### Models With Balanced Data

# %%
lgb_bal = LGBMClassifier(class_weight='balanced')

# %%
lgb_bal.fit(X_train_fs,y_train)
pred = lgb_bal.predict(X_test_fs)

# Evaluation 
print("Accuracy : ",accuracy_score(y_test,pred))
print("Precision : ",precision_score(y_test,pred))
print("Recall : ",recall_score(y_test,pred))
print("F1_score : ",f1_score(y_test,pred))
# Out:
# [LightGBM] [Info] Number of positive: 4231, number of negative: 31937
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003124 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 685
# [LightGBM] [Info] Number of data points in the train set: 36168, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# Accuracy :  0.8271591286077629
# Precision :  0.389010989010989
# Recall :  0.8364839319470699
# F1_score :  0.5310531053105311

# %% [markdown]
# #### Using the Smote

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)

X_train_smote, y_train_smote = smote.fit_resample(X_train_fs,y_train)

# %%
print(y_train.value_counts())
# Out:
# target
# 0    31937
# 1     4231
# Name: count, dtype: int64

# %%
print(y_train_smote.value_counts())
# Out:
# target
# 0    31937
# 1    31937
# Name: count, dtype: int64

# %%
# Gradient Boosting With Smote
gb_smote = GradientBoostingClassifier(random_state=42)

gb_smote.fit(X_train_smote,y_train_smote)

pred = gb_smote.predict(X_test_fs)

# Evaluation 
print("Accuracy : ",accuracy_score(y_test,pred))
print("Precision : ",precision_score(y_test,pred))
print("Recall : ",recall_score(y_test,pred))
print("F1_score : ",f1_score(y_test,pred))
# Out:
# Accuracy :  0.8533672453831693
# Precision :  0.42895015906680806
# Recall :  0.7646502835538752
# F1_score :  0.5495923913043478

# %%
# Gradient Boosting With Smote
lgb_smote = LGBMClassifier(random_state=42)

lgb_smote.fit(X_train_smote,y_train_smote)

pred = lgb_smote.predict(X_test_fs)

# Evaluation 
print("Accuracy : ",accuracy_score(y_test,pred))
print("Precision : ",precision_score(y_test,pred))
print("Recall : ",recall_score(y_test,pred))
print("F1_score : ",f1_score(y_test,pred))
# Out:
# [LightGBM] [Info] Number of positive: 31937, number of negative: 31937
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004765 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1301
# [LightGBM] [Info] Number of data points in the train set: 63874, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Accuracy :  0.8857679973460135
# Precision :  0.509448223733938
# Recall :  0.6370510396975425
# F1_score :  0.5661486770264594

# %% [markdown]
# ### Insight
# -----
#
# Applying SMOTE significantly improved the model's ability to identify potential subscribers.
#
# - Recall increased from 39.0% to 76.5%,
# - while F1 Score improved from 0.4856 to 0.5496.
#
# Although precision decreased, the model became more suitable for marketing campaigns where capturing potential subscribers is prioritized.

# %%
prob = gb_smote.predict_proba(X_test_fs)[:,1]

print("ROC AUC :", roc_auc_score(y_test, prob))
print("Log Loss :", log_loss(y_test, prob))
# Out:
# ROC AUC : 0.8971276483671533
# Log Loss : 0.3164930364713251

# %%
Selected_Models = {
    "GB_Baseline": {
        "model": gb_model,
        "X_test": X_test
    },

    "GB_FS": {
        "model": gb_fs,
        "X_test": X_test_fs
    },

    "GB_SMOTE": {
        "model": gb_smote,
        "X_test": X_test_fs
    },

    "LGB_Baseline": {
        "model": lgb_model,
        "X_test": X_test
    },

    "LGB_Balanced": {
        "model": lgb_bal,
        "X_test": X_test_fs
    },

    "LGB_SMOTE": {
        "model": lgb_smote,
        "X_test": X_test_fs
    }
}

# %%
for name, model in Selected_Models.items():
    print(name)
# Out:
# GB_Baseline
# GB_SMOTE
# LGB_Baseline
# LGB_Balanced
# LGB_SMOTE

# %%
results = []

for name, info in Selected_Models.items():

    model = info["model"]
    X_eval = info["X_test"]

    pred = model.predict(X_eval)

    prob = model.predict_proba(X_eval)[:,1]

    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test,pred),
        "Precision": precision_score(y_test,pred),
        "Recall": recall_score(y_test,pred),
        "F1 Score": f1_score(y_test,pred),
        "ROC AUC": roc_auc_score(y_test,prob),
        "Log Loss": log_loss(y_test,prob)
    })

results_df = pd.DataFrame(results)

# %%
results_df.sort_values(
    by=["Recall","F1 Score"],
    ascending=False
)
# Out:
#           Model  Accuracy  Precision    Recall  F1 Score   ROC AUC  Log Loss
# 4  LGB_Balanced  0.827159   0.389011  0.836484  0.531053  0.901732  0.370724
# 2      GB_SMOTE  0.853367   0.428950  0.764650  0.549592  0.897128  0.316493
# 5     LGB_SMOTE  0.885768   0.509448  0.637051  0.566149  0.898208  0.255867
# 1         GB_FS  0.903240   0.642302  0.390359  0.485597  0.902921  0.230711
# 3  LGB_Baseline  0.900254   0.619266  0.382798  0.473131  0.903422  0.228222
# 0   GB_Baseline  0.902245   0.638978  0.378072  0.475059  0.902548  0.230952

# %% [markdown]
# ### Insights
#
# 1. We have the better LogLoss and Better F1 Score compared to the models which have low Log Loss and Low Recall Score
# 2. Model which have High Recall have more LogLoss but LightGBM Smote having the mean in both of them
#
#
# So we select the Light GBM Smote Model and GBM Smote for the Hyperparameter Tuning

# %% [markdown]
# Model For the Hyperparameter Tuning
# 1. LightGBM Smote
# 2. GBM Smote

# %% [markdown]
# ### Step 4 : Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# #### Light Gradient Boosing Tuning

# %%
param_grid = {
    'n_estimators': [100, 200, 300, 500],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7, 10],
    'num_leaves': [15, 31, 63, 127],
    'min_child_samples': [10, 20, 30, 50],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0]}

lgb_tune = RandomizedSearchCV(
    estimator=LGBMClassifier(random_state=42),
    param_distributions=param_grid,
    n_iter=30,
    scoring='f1',
    cv=5,
    n_jobs=-1,
    random_state=42)

# %%
lgb_tune.fit(X_train_smote,y_train_smote)
# Out:
# [LightGBM] [Info] Number of positive: 31937, number of negative: 31937
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005124 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1301
# [LightGBM] [Info] Number of data points in the train set: 63874, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# RandomizedSearchCV(cv=5, estimator=LGBMClassifier(random_state=42), n_iter=30,
#                    n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.8, 0.9, 1.0],
#                                         'learning_rate': [0.01, 0.05, 0.1],
#                                         'max_depth': [3, 5, 7, 10],
#                                         'min_child_samples': [10, 20, 30, 50],
# ...

# %%
pred = lgb_tune.predict(X_test_fs)

# %%
print("Accuracy :",accuracy_score(y_test,pred))
print("Precision :",precision_score(y_test,pred))
print("Recall :",recall_score(y_test,pred))
print("F1 :",f1_score(y_test,pred))
# Out:
# Accuracy : 0.8860997456596262
# Precision : 0.5121317157712305
# Recall : 0.558601134215501
# F1 : 0.5343580470162749

# %%
print(lgb_tune.best_params_)
print(lgb_tune.best_score_)
# Out:
# {'subsample': 0.9, 'num_leaves': 127, 'n_estimators': 100, 'min_child_samples': 10, 'max_depth': 10, 'learning_rate': 0.1, 'colsample_bytree': 0.9}
# 0.9129138584959291

# %%
y_test
# Out:
# 1392     0
# 7518     0
# 12007    0
# 5536     0
# 29816    0
#         ..
# 12636    0
# 13364    0
# 16102    0
# 42097    0
# 31033    0
# Name: target, Length: 9043, dtype: int64

# %%
prob = lgb_tune.predict_proba(X_test_fs)[:,1]
prob
# Out:
# array([0.00306428, 0.00278514, 0.00187097, ..., 0.10656537, 0.00275255,
#        0.00431665], shape=(9043,))

# %%
loss = log_loss(y_test, prob)

print(loss)
# Out:
# 0.2558671842913362

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[7390,  595],
#        [ 427,  631]])

# %%
lresults = pd.DataFrame(lgb_tune.cv_results_)
lresults[["mean_test_score","rank_test_score","params"]].sort_values(by="rank_test_score").head()
# Out:
#     mean_test_score  rank_test_score  \
# 10         0.912914                1
# 26         0.906219                2
# 25         0.905194                3
# 20         0.901111                4
# 4          0.898218                5
#
#                                                params
# 10  {'subsample': 0.9, 'num_leaves': 127, 'n_estim...
# 26  {'subsample': 0.9, 'num_leaves': 63, 'n_estima...
# 25  {'subsample': 1.0, 'num_leaves': 63, 'n_estima...
# 20  {'subsample': 0.9, 'num_leaves': 63, 'n_estima...
# 4   {'subsample': 0.9, 'num_leaves': 31, 'n_estima...

# %% [markdown]
# #### Gradient Boosing Tuning

# %%
gb_params = {"n_estimators":[100,200,300,500],
            "learning_rate":[0.01,0.03,0.05,0.1],
            "max_depth":[3,4,5,6,7],
            "subsample":[0.7,0.8,0.9,1.0],
            "min_samples_split":[2,5,10,20],
            "min_samples_leaf":[1,2,4,8]}

gb_tune = RandomizedSearchCV(estimator=GradientBoostingClassifier(random_state=42),
    param_distributions=gb_params,
    n_iter=30,
    scoring="f1",
    cv=5,
    verbose=3,
    random_state=42,
    n_jobs=-1)

# %%
gb_tune.fit(X_train_smote,y_train_smote)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# RandomizedSearchCV(cv=5, estimator=GradientBoostingClassifier(random_state=42),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions={'learning_rate': [0.01, 0.03, 0.05,
#                                                           0.1],
#                                         'max_depth': [3, 4, 5, 6, 7],
#                                         'min_samples_leaf': [1, 2, 4, 8],
#                                         'min_samples_split': [2, 5, 10, 20],
#                                         'n_estimators': [100, 200, 300, 500],
#                                         'subsample': [0.7, 0.8, 0.9, 1.0]},
#                    random_state=42, scoring='f1', verbose=3)

# %%
results = pd.DataFrame(gb_tune.cv_results_)
results[["mean_test_score","rank_test_score","params"]].sort_values(by="rank_test_score").head()
# Out:
#     mean_test_score  rank_test_score  \
# 22         0.903773                1
# 5          0.901999                2
# 16         0.899725                3
# 13         0.899643                4
# 1          0.898880                5
#
#                                                params
# 22  {'subsample': 0.9, 'n_estimators': 500, 'min_s...
# 5   {'subsample': 0.7, 'n_estimators': 200, 'min_s...
# 16  {'subsample': 0.8, 'n_estimators': 300, 'min_s...
# 13  {'subsample': 1.0, 'n_estimators': 300, 'min_s...
# 1   {'subsample': 0.7, 'n_estimators': 500, 'min_s...

# %%
best_gb = gb_tune.best_estimator_
gb_pred = best_gb.predict(X_test_fs)

print("Accuracy :",accuracy_score(y_test,pred))
print("Precision :",precision_score(y_test,pred))
print("Recall :",recall_score(y_test,pred))
print("F1 :",f1_score(y_test,pred))
# Out:
# Accuracy : 0.8860997456596262
# Precision : 0.5121317157712305
# Recall : 0.558601134215501
# F1 : 0.5343580470162749

# %%
print(gb_tune.best_params_)
print(gb_tune.best_score_)
# Out:
# {'subsample': 0.9, 'n_estimators': 500, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_depth': 7, 'learning_rate': 0.03}
# 0.9037733484911635

# %%
prob = best_gb.predict_proba(X_test_fs)[:,1]
roc = roc_auc_score(y_test,prob)
log_loss = log_loss(y_test,prob)


print("ROC Score : ",roc)
print("Log Loss : ",log_loss)
# Out:
# ROC Score :  0.8950488451290404
# Log Loss :  0.2542995856967258

# %%
confusion_matrix(y_test,gb_pred)
# Out:
# array([[7390,  595],
#        [ 427,  631]])

# %%
probs = gb_smote.predict_proba(X_test_fs)[:,1]

# %%
len(probs)
# Out:
# 9043

# %% [raw]
# # Currently we have the 4 models to verify and check for the new Threshold optimization
#
# 1. gb_smote
# 2. lgb_smote
#
# 3. gb_tune
# 4. lgb_tune

# %% [markdown]
# ### Step 5 : Threshold Optimization

# %%
probs = gb_smote.predict_proba(X_test_fs)[:,1]

threshold_results = []

for threshold in np.arange(0.20, 0.81, 0.05):

    preds = (probs >= threshold).astype(int)

    threshold_results.append({
        "Threshold": round(threshold,2),
        "Accuracy": accuracy_score(y_test,preds),
        "Precision": precision_score(y_test,preds),
        "Recall": recall_score(y_test,preds),
        "F1": f1_score(y_test,preds)
    })

threshold_df = pd.DataFrame(threshold_results)

threshold_df
# Out:
#     Threshold  Accuracy  Precision    Recall        F1
# 0        0.20  0.720336   0.285506  0.925331  0.436372
# 1        0.25  0.758377   0.313719  0.896975  0.464854
# 2        0.30  0.786133   0.340495  0.883743  0.491588
# 3        0.35  0.804268   0.359289  0.859168  0.506689
# 4        0.40  0.820303   0.377960  0.829868  0.519373
# 5        0.45  0.839434   0.405561  0.799622  0.538168
# 6        0.50  0.853367   0.428950  0.764650  0.549592
# 7        0.55  0.866527   0.455093  0.713611  0.555760
# 8        0.60  0.876921   0.481406  0.672968  0.561293
# 9        0.65  0.883999   0.503486  0.614367  0.553427
# 10       0.70  0.889307   0.526027  0.544423  0.535067
# 11       0.75  0.893288   0.554900  0.444234  0.493438
# 12       0.80  0.896716   0.606164  0.334594  0.431181

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

plt.plot(
    threshold_df["Threshold"],
    threshold_df["Precision"],
    marker="o",
    label="Precision"
)

plt.plot(
    threshold_df["Threshold"],
    threshold_df["Recall"],
    marker="o",
    label="Recall"
)

plt.plot(
    threshold_df["Threshold"],
    threshold_df["F1"],
    marker="o",
    label="F1"
)

plt.xlabel("Threshold")
plt.ylabel("Score")

plt.title("Threshold Optimization")

plt.legend()

plt.grid(True)

plt.show()

# %%
best_row = threshold_df.loc[
    threshold_df["F1"].idxmax()
]

best_row
# Out:
# Threshold    0.600000
# Accuracy     0.876921
# Precision    0.481406
# Recall       0.672968
# F1           0.561293
# Name: 8, dtype: float64

# %%
np.arange(0.10,0.91,0.02)

probs = gb_tune.predict_proba(X_test_fs)[:,1]

threshold_results = []

for threshold in np.arange(0.10,0.91,0.02): #np.arange(0.20, 0.81, 0.05):

    preds = (probs >= threshold).astype(int)

    threshold_results.append({
        "Threshold": round(threshold,2),
        "Accuracy": accuracy_score(y_test,preds),
        "Precision": precision_score(y_test,preds),
        "Recall": recall_score(y_test,preds),
        "F1": f1_score(y_test,preds)
    })

threshold_df = pd.DataFrame(threshold_results)

threshold_df
# Out:
#     Threshold  Accuracy  Precision    Recall        F1
# 0        0.10  0.738693   0.297171  0.903592  0.447251
# 1        0.12  0.760257   0.314753  0.891304  0.465220
# 2        0.14  0.776733   0.329307  0.876181  0.478699
# 3        0.16  0.790335   0.343071  0.865784  0.491416
# 4        0.18  0.804490   0.358678  0.851607  0.504762
# 5        0.20  0.814663   0.370603  0.836484  0.513639
# 6        0.22  0.824284   0.383091  0.822306  0.522679
# 7        0.24  0.832357   0.395147  0.815690  0.532387
# 8        0.26  0.838991   0.404876  0.800567  0.537778
# 9        0.28  0.844410   0.412706  0.779773  0.539745
# 10       0.30  0.850492   0.423197  0.765595  0.545087
# 11       0.32  0.856353   0.434261  0.752363  0.550675
# 12       0.34  0.860445   0.442111  0.736295  0.552482
# 13       0.36  0.865310   0.452607  0.722117  0.556446
# 14       0.38  0.869181   0.461444  0.706994  0.558417
# 15       0.40  0.870397   0.463415  0.682420  0.551988
# ...

# %%
best_row = threshold_df.loc[
    threshold_df["F1"].idxmax()
]

best_row
# Out:
# Threshold    0.380000
# Accuracy     0.869181
# Precision    0.461444
# Recall       0.706994
# F1           0.558417
# Name: 14, dtype: float64

# %% [markdown]
# ### Insight
# 1. Threshold optimization improved the balance between precision and recall, increasing the F1 score while maintaining strong subscriber detection capability.
#
# 2. The final model successfully identified approximately 67% of potential subscribers while improving the quality of predicted leads.

# %%
probs = lgb_smote.predict_proba(X_test_fs)[:,1]

threshold_results = []

for threshold in np.arange(0.20, 0.81, 0.05):

    preds = (probs >= threshold).astype(int)

    threshold_results.append({
        "Threshold": round(threshold,2),
        "Accuracy": accuracy_score(y_test,preds),
        "Precision": precision_score(y_test,preds),
        "Recall": recall_score(y_test,preds),
        "F1": f1_score(y_test,preds)
    })

threshold_df = pd.DataFrame(threshold_results)

threshold_df
# Out:
#     Threshold  Accuracy  Precision    Recall        F1
# 0        0.20  0.807254   0.363383  0.861059  0.511080
# 1        0.25  0.829592   0.392332  0.831758  0.533172
# 2        0.30  0.844852   0.414899  0.794896  0.545219
# 3        0.35  0.858012   0.438184  0.757089  0.555094
# 4        0.40  0.866969   0.456140  0.712665  0.556252
# 5        0.45  0.876811   0.481233  0.678639  0.563137
# 6        0.50  0.885768   0.509448  0.637051  0.566149
# 7        0.55  0.889085   0.523727  0.573724  0.547587
# 8        0.60  0.890634   0.534813  0.500945  0.517326
# 9        0.65  0.896052   0.573201  0.436673  0.495708
# 10       0.70  0.896937   0.600318  0.356333  0.447212
# 11       0.75  0.894946   0.620000  0.263705  0.370027
# 12       0.80  0.891961   0.639175  0.175803  0.275760

# %% [markdown]
# ### Step 6 : Final Model Comparison

# %% [markdown]
# ## Final Model Comparison
#
# | Model | Accuracy | Precision | Recall | F1 Score | ROC-AUC | Log Loss | Remarks |
# |---------|---------:|---------:|---------:|---------:|---------:|---------:|---------|
# | GB_Baseline | 0.9021 | 0.6384 | 0.3771 | 0.4742 | 0.9025 | 0.2310 | Strong baseline model |
# | GB_FS | 0.9032 | 0.6423 | 0.3904 | 0.4856 | 0.9029 | 0.2307 | Feature selection improved performance |
# | GB_SMOTE | 0.8534 | 0.4290 | 0.7647 | 0.5496 | 0.8971 | 0.3165 | Highest recall model |
# | LGB_Baseline | 0.9003 | 0.6193 | 0.3828 | 0.4731 | 0.9034 | 0.2282 | Best probability ranking |
# | LGB_Balanced | 0.8272 | 0.3890 | 0.8365 | 0.5311 | 0.9017 | 0.3707 | Maximum subscriber detection |
# | LGB_SMOTE | 0.8858 | 0.5094 | 0.6371 | 0.5661 | 0.8982 | 0.2559 | Best F1 score before tuning |
# | GB_Tuned | 0.8870 | 0.5147 | 0.5964 | 0.5525 | 0.8950 | 0.2543 | Tuned Gradient Boosting |
# | GB_SMOTE + Threshold (0.60) | 0.8769 | 0.4814 | 0.6730 | 0.5613 | 0.8971 | 0.3165 | Best precision-recall balance |

# %%
import pickle

# %%
import joblib

# %%
final_artifact = {
    "model": gb_smote,
    "threshold": 0.60,
    "features": X_train_fs.columns.tolist()
}

joblib.dump(
    final_artifact,
    "bank_marketing_final.pkl"
)
# Out:
# ['bank_marketing_final.pkl']

# %% [markdown]
# ### Later we can load this way

# %%
artifact = joblib.load(
    "bank_marketing_final.pkl"
)

model = artifact["model"]
threshold = artifact["threshold"]
features = artifact["features"]

# %%
final_artifact = {
    "model_name": "Gradient Boosting + SMOTE",
    "model": gb_smote,
    "threshold": 0.60,
    "features": X_train_fs.columns.tolist(),
    "metrics": {
        "accuracy": 0.8769,
        "precision": 0.4814,
        "recall": 0.6730,
       "f1": 0.5613
    }
}

# %%
# Loading the Pickle File to Save the Artifact model 
joblib.dump(final_artifact,"bank_marketing_final.pkl")
# Out:
# ['bank_marketing_final.pkl']

# %%
# we can ceck what are values we can use in the model
artifact = joblib.load("bank_marketing_final.pkl")
artifact.keys()
# Out:
# dict_keys(['model_name', 'model', 'threshold', 'features', 'metrics'])

# %%
model = artifact["model"]

# %%
# Metrics
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,log_loss,roc_auc_score

# %%
pred = model.predict(X_test_fs)

# %%
accuracy_score(y_test,pred)
# Out:
# 0.8533672453831693

# %%
print(
"Accuracy", accuracy_score(y_test,pred),
"Precision", precision_score(y_test,pred),
"Recall", recall_score(y_test,pred),
"F1", f1_score(y_test,pred))
# Out:
# Accuracy 0.8533672453831693 Precision 0.42895015906680806 Recall 0.7646502835538752 F1 0.5495923913043478

# %%
pwd
# Out:
# 'C:\\Users\\midhu\\OneDrive\\Documents\\Inno_Python_files\\Self_Working_Material\\Class_Notes_All\\Machine_learning\\Projects\\banking_marketing_campaign_prediction\\notebooks'

# %%
df = pd.read_csv("../data/train.csv",sep=";")

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.rename(columns={"y":"target"}, inplace=True)
df.rename(columns={"default":"default_credit"}, inplace=True)
df.rename(columns={"housing":"housing_loan"}, inplace=True)
df.rename(columns={"loan":"personal_loan"}, inplace=True)
df.rename(columns={"contact":"contact_type"}, inplace=True)
df.rename(columns={"poutcome":"previous_outcome"}, inplace=True)
df.rename(columns={"pdays":"no_time_contacted_days_before"}, inplace=True)
df.rename(columns={"duration":"last_call_duration"}, inplace=True)
df.rename(columns={"campaign":"contacts_in_campaign"}, inplace=True)
df.rename(columns={"previous":"contacted_in_before_campaing"}, inplace=True)

# %%
df.to_csv("train_new.csv")

# %%
import pandas as pd

# %%
import os
os.listdir("../data")
# Out:
# ['test.csv', 'train.csv']

# %%
df_1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
X_train_fs.columns
# Out:
# Index(['age', 'education', 'housing_loan', 'personal_loan',
#        'contacts_in_campaign', 'contacted_in_before_campaing', 'balance_log',
#        'duration_log', 'job_blue-collar', 'job_student', 'marital_married',
#        'marital_single', 'previous_outcome_other', 'previous_outcome_success',
#        'previous_outcome_unknown', 'contact_type_telephone',
#        'contact_type_unknown'],
#       dtype='object')

# %%
test = pd.read_csv("./data/test.csv",sep=";")

# %%
test
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
import joblib

joblib.dump(
    scaler,
    "./models/scaler.pkl"
)

joblib.dump(
    education_map,
    "./models/education_map.pkl"
)
